# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import subprocess
import unittest

# %%
# %run ../tests/test_data_processing.py

# %%
df
# Out:
#       Age  Gender  Ethnicity  EducationLevel      BMI  Smoking  \
# 0      63       0          1               0  17.5150        0
# 1      26       1          2               2  22.5180        0
# 2      57       0          2               1  17.5150        0
# 3      40       1          2               1  37.4905        0
# 4      61       0          0               3  17.5150        0
# ...   ...     ...        ...             ...      ...      ...
# 2387   43       1          0               2  27.5085        0
# 2388   18       1          0               1  22.5180        0
# 2389   54       0          3               2  37.4905        0
# 2390   46       1          0               2  22.5180        0
# 2391   26       1          0               0  27.5085        1
#
#       PhysicalActivity  DietQuality  SleepQuality  PollutionExposure  ...  \
# 0             0.894448     5.488696      8.701003           7.388481  ...
# ...

# %%
# Create a test suite

suite = unittest.TestSuite()

# %%
suite
# Out:
# <unittest.suite.TestSuite tests=[]>

# %%
# Add the test case created by the factory function

suite.addTest(create_test_case(df, numerical_features))

# %%
# Run the tests

runner = unittest.TextTestRunner(verbosity=2)
runner.run(suite)
# Out:
# test_scale_features (builtins.create_test_case.<locals>.DynamicTestCase.test_scale_features) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.018s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>
